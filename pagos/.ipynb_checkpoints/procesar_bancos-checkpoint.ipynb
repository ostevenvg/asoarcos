# %%
from utilities import *

# %%
def get_casas_from_description(d):
    if not isinstance(d,str):
        return []
    casas = []
    d=d.upper()
    
    m = re.match(r'.*CASAS?\s*([\d\-Y,\s\/_]*)',d)
    if m:
        casas = m.group(1)
        if casas:
            casas = re.sub('-|_|\/|\s','',casas)
            casas = casas.replace('Y',',').split(',')
    #get keyworks
    
    casas_ = []
    for c in casas:
        if len(c) == 1:
            casas_.append('100' + c)
        if len(c) == 2:
            casas_.append('10' + c)
        elif len(c) == 3:
            casas_.append('1' + c)
        else:
            casas_.append(c)
        
    return casas_

def get_casa_from_customer(c):
    out = [False, None, np.nan]
    
    if isinstance(c, str):
        c = c.upper()
        #divide casa and name. Example: Casa 1209 Jaime Barrientos"
        m = re.match(r'CASA (\d+(-[A,B,C,D,E])?([-/]\d+)?)\s*-?\s*(.*)', c, re.I)
        if m:
            if m.group(4):
                name = m.group(4).upper()
            else:
                name = np.nan
            out = [True, m.group(1), name] #return: is casa, casa, name
    
    return out 

def check_payment(amount, m=None, recursive=True):
    if not m:
        m = main_config['mensualidad']

    q = int(amount / m)
    r = amount % m
    
    if q > 0 and r == 0 :
        #mensualidad exacta
        return q
    elif q > 0 and r == q * main_config['agua lago']:
        #mensualidad con agua lagos exacta
        return q
    else:
        #probar mensualidad anterior
        if recursive:
            return check_payment(amount, m=main_config['mensualidad anterior'], recursive=False)
        else:
            return np.nan

def fuzzy_match_customer(description, casas):
    if not isinstance(description,str):
        return []
    ratio = 0
    customers = []
    
    #try first with casa
    for index, row in df_customers[df_customers['is_casa']].iterrows():
        for c in casas:
            if c == row['casa']:
                 customers.append(row['Customer'])
    #fuzzy match
    if not customers:
        d = description.upper()
        ignores = ["TRANSFERENC","BANCOBCR","DEPOSITOS", "CREDITO",
               "INTERBANCARI", "SINPE", "MOVIL", "PIN ENTRANTE",
               "TEF DE:", "-", "_", "*"]
        for ignore in ignores:
            d = d.replace(ignore,' ')

        fm = process.extract(d, dict_customers.keys(),  scorer=fuzz.token_set_ratio, limit=1)
        if fm[0][1] > 80:
            customers.append(dict_customers[fm[0][0]])
        
    return customers


def fix_credit_column(c):
    out = c
    if isinstance(c,str) or isinstance(c,int) or isinstance(c,float):
        c = str(c)
        m = re.search(r'(.*)\+', c, re.I)
        if m:
            return m.group(1)
        m = re.search(r'(.*)\-', c, re.I)
        if m:
            return np.nan
        m = re.search(r'\-(.*)', c, re.I)
            
        if m:
            return np.nan
    return out 

def process_customers_excel():
    df = gendf_from_excel_table("data/clientes_quickbooks.xlsx",['Customer', 'Email'],stop_if_empty=False)
    
    #split casa and name
    df['is_casa'], df['casa'], df['name'] = zip(*df['Customer'].map(get_casa_from_customer))
    
    return df[['Customer','is_casa','casa','name']]


def process_bank_excel(bank,bank_config):
    #swaps key and values
    bank_cols = {v: k for k, v in bank_config[bank].items()}

    #get which lines have the table we want to read with pandas
    excel_bank = "data/banco_{}.xlsx".format(bank)
    if not os.path.exists(excel_bank):
         excel_bank = "data/banco_{}.xls".format(bank)
    
    if not os.path.exists(excel_bank):
        print("INFO: File {}(x) not found. Bank {} not processed.".format(excel_bank, bank))
        return pd.DataFrame([])
    
    #create dataframe with normalized columns
    bankdf = gendf_from_excel_table(excel_bank,bank_cols)
    if bankdf.empty:
        print("INFO: Columns {} not found in file {}. Check configuration".format(bank_cols, excel_bank))
        return bankdf
    
    bankdf.rename(columns=bank_cols, inplace=True)
    bankdf.replace(0, np.nan, inplace=True)
    bankdf.replace('''''', np.nan, inplace=True)
    
    #Fix credito colums when +- symbols are used
    bankdf['credito_tmp'] = bankdf['credito'].apply(fix_credit_column)
    bankdf['credito'] = bankdf['credito_tmp']
    
    #keep only rows with credits
    bankdf.dropna(axis=0, subset="credito", inplace=True)
    
    #keep only configured columns
    bankdf=bankdf[1:][bank_cols.values()]
    
    #add bank columns
    bankdf.insert(0,'excel',excel_bank)
    bankdf.insert(0,'banco',bank)
    bankdf['casas']=bankdf['descripcion'].apply(get_casas_from_description)
    
    #Try to guess customers
    bankdf['customer'] = bankdf.apply(lambda x: fuzzy_match_customer(x['descripcion'], x['casas']), axis=1)
    bankdf['customer'] = bankdf['customer'].apply(lambda x: ', '.join(x) if isinstance(x,list) else '')


    #Try to numero de casas and meses pagados
    bankdf['num casas'] = bankdf['casas'].apply(lambda x: len(x) if isinstance(x,list) else '')
    bankdf.credito.astype('float')
    bankdf['num meses'] = bankdf['credito'].apply(check_payment)
    
    return bankdf

# %%
########### MAIN ############

#Load customers
df_customers = process_customers_excel()
dict_customers = df_customers[df_customers['is_casa']][['Customer', 'name']].dropna().set_index('name').to_dict()['Customer']
casa_customers = list(df_customers[df_customers['is_casa']]['Customer'])
#df_customers.to_excel('out/clientes.xlsx')

#Load configuration
df_main_config = pd.read_excel("config.xlsx", sheet_name="principal").dropna(axis=1, how="all")
main_config = df_main_config.set_index("item").to_dict()['valor']
df_bank_config = pd.read_excel("config.xlsx", sheet_name="columnas bancos").dropna(axis=1, how="all")
bank_config = df_bank_config.set_index("columna").to_dict()

#Load all banks data
bank_dfs = []
for bank in bank_config:
    print("Processing banco: " + bank)
    bank_df = process_bank_excel(bank, bank_config)
    if not bank_df.empty:
        bank_dfs.append(bank_df)
df = pd.concat(bank_dfs).reset_index(drop=True)

#Save excel
if not os.path.exists("out"):
    os.makedirs("out")
df.to_excel('out/bancos.xlsx', index=False)

print("Task completed.")
# Out:
# Processing banco: bcr
# Processing banco: bac
# Processing banco: bn
# Task completed.

# %%
dict_customers
# Out:
# {'IKON CR': 'Casa 1002 Ikon CR',
#  'MAIT S.A.': 'Casa 1004 Mait S.A.',
#  'LUIS GERARDO BARQUERO': 'Casa 1006 Luis Gerardo Barquero',
#  'YUNIEL GARCIA': 'Casa 1008 Yuniel Garcia',
#  'LOTE VACIO': 'Casa 1009  LOTE VACIO',
#  'MARCELA ESQUIVEL MARTINEZ': 'Casa 1010 Marcela Esquivel Martinez',
#  'MA. EUGENIA VASQUEZ NARANJO': 'Casa 1011 Ma. Eugenia Vasquez Naranjo',
#  'JOHNNY QUESADA ALFARO': 'Casa 1062-B  Johnny Quesada Alfaro',
#  'FRANK ALFARO': 'Casa 1063 Frank Alfaro',
#  'MAURICIO GONZALEZ ARAGON': 'Casa 1064- Mauricio Gonzalez Aragon',
#  'ANA MORERA': 'Casa 1065 Ana Morera',
#  'LILLIANA COLOMBARI': 'Casa 1066 Lilliana Colombari',
#  'DELIA MARTINEZ BENAVIDES': 'Casa 1068 Delia Martinez Benavides',
#  'CARMEN ROJAS': 'Casa 1070 Carmen Rojas',
#  'EDUARDO ARCE DIAZ': 'Casa 1072 Eduardo Arce Diaz',
#  'JUMER E HIJOS LIMITADA': 'Casa 1098 Jumer e Hijos Limitada',
#  'SHEEPHORN LTD': 'Casa 1074 SHEEPHORN LTD',
#  'RODOLFO SOTO': 'Casa 1075 Rodolfo Soto',
#  'STEPHANIE HERNANDEZ  LOPEZ': 'Casa 1076- Stephanie Hernandez  Lopez',
#  'RODRIGO CONTRERAS': 'Casa 1076-1077 Rodrigo Contreras',
#  'WOLFGANG GIHR': 'Casa 1078 Wolfgang Gihr',
#  'ANA MIRTA FELDMAN': 'Casa 1081- Ana Mirta Feldman',
#  'EDWARD MONTANO': 'Casa 1083 Edward Montano',
#  'IMPORTACIONES CONCORDE LIMITADA': 'Casa 1084 Importaciones Concorde Limitada',
#  'HILDA ARROYO': 'Casa 1085 Hilda Arroyo',
#  'URSULA ARGILES': 'Casa 1086 Ursula Argiles',
#  'ALVARO/ERLINDA MORALES': 'Casa 1087 Alvaro/Erlinda Morales',
#  'ARTURO SUAREZ VIQUEZ, CEDULA 107330072': 'Casa 1088 Arturo Suarez Viquez, Cedula 107330072',
#  'GRACIELA BACIGALUPO': 'Casa 1089-A Graciela Bacigalupo',
#  'ERIKA TRUQUE BARRANTES': 'Casa 1089-B Erika Truque Barrantes',
#  'RUDY RODRIGUEZ': 'Casa 1089-C  Rudy Rodriguez',
#  'IRENE REVUELTA SANCHEZ': 'Casa 1090 Irene Revuelta Sanchez',
#  'CECILIA ALPIZAR': 'Casa 1092 Cecilia Alpizar',
#  'FERNANDO QUIROS': 'Casa 1093 Fernando Quiros',
#  'OLGA CHAVES': 'Casa 1094 Olga Chaves',
#  'MAX LOYA': 'Casa 1095 Max Loya',
#  'LUCRECIA ALVARADO GALLO': 'Casa 1096 Lucrecia Alvarado Gallo',
#  'KABRUK S.A.': 'Casa 1099 Kabruk S.A.',
#  'MAURICIO AGUILAR CASTRO': 'Casa 1100 Mauricio Aguilar Castro',
#  'AGUILU S.A.': 'Casa 1101-B Aguilu S.A.',
#  'INDIANA NUNEZ': 'Casa 1102 Indiana Nunez',
#  'SIGRID BRENES': 'Casa 1103 Sigrid Brenes',
#  'REYNA MARTINEZ GAVARRETE': 'Casa 1104 Reyna Martinez Gavarrete',
#  'JOSE LUIS BEITA': 'Casa 1106 Jose Luis Beita',
#  'CIEN MIL DIECISEIS S.A': 'Casa 1107-A Cien Mil Dieciseis S.A',
#  'CIEN MIL DIECISEIS SA': 'Casa 1107-B Cien Mil Dieciseis SA',
#  'SARA VIANNEY CASTILLO SALAZAR': 'Casa 2012 Sara Vianney Castillo Salazar',
#  'MARK BARLES': 'Casa 2015 Mark Barles',
#  'JORGE ENRIQUE VASQUEZ AGUILAR': 'Casa 2016 Jorge Enrique Vasquez Aguilar',
#  'JOSE MEZA': 'Casa 2017 Jose Meza',
#  'CIEN MIL DIECISEIS S.A.': 'Casa 2018 Cien Mil Dieciseis S.A.',
#  'MARIA LUISA RAMIREZ': 'Casa 2020 Maria Luisa Ramirez',
#  'RODRIGO LI GUZMAN': 'Casa 2021 Rodrigo Li Guzman',
#  'GUISELLE SIBAJA': 'Casa 2022 Guiselle Sibaja',
#  'MARVA SPENCE': 'Casa 2023 Marva Spence',
#  'NAPOLEON MURILLO': 'Casa 2024 Napoleon Murillo',
#  'GERARDO CHACON': 'Casa 2025 Gerardo Chacon',
#  'MARTA DORIS PINEDA': 'Casa 2026-A Marta Doris Pineda',
#  'RAMON MIRANDA': 'Casa 2026-B Ramon Miranda',
#  'JUAN CARLOS RUDIN': 'Casa 2026-C Juan Carlos Rudin',
#  'EDWIN LUGO CALDERON': 'Casa 2027 Edwin Lugo Calderon',
#  'ERNESTO LUGO CALDERON': 'Casa 2028 Ernesto Lugo Calderon',
#  'CLEMENCIA MURILLO CHAVES': 'Casa 2029 Clemencia Murillo Chaves',
#  'JUAN Y PAQUITA S.A.': 'Casa 2030 Juan y Paquita S.A.',
#  'ALEJANDRO LAPENTTI': 'Casa 2031-2032 Alejandro Lapentti',
#  'MARIOSCA S.A.': 'Casa 2033 Mariosca S.A.',
#  'INVERSIONES RILO S.A.': 'Casa 2034-C Inversiones Rilo S.A.',
#  'JOSE GREEN': 'Casa 2037 Jose Green',
#  'EITERER REINHOLD': 'Casa 2039 Eiterer Reinhold',
#  'KATIA RIVERA': 'Casa 2041-B Katia Rivera',
#  'SHIRLEY ZUNIGA MARTINEZ': 'Casa 2042 Shirley Zuniga Martinez',
#  'ARMERIA CARL CLAUBER S.A': 'Casa 2043 Armeria Carl Clauber S.A',
#  'GLORIA MARTINEZ GAVARRETE': 'Casa 2044 Gloria Martinez Gavarrete',
#  'TOSHIO TAMAKI': 'Casa 2045 Toshio Tamaki',
#  'YOSHIO NARA': 'Casa 2046 Yoshio Nara',
#  'HUGO D. QUINTANA SALMERON': 'Casa 2050 Hugo D. Quintana Salmeron',
#  'MARTA RAMIREZ': 'Casa 2051 Marta Ramirez',
#  'JIMMY BUTMAN': 'Casa 2054 Jimmy Butman',
#  '3-101-633201 S.A': 'Casa 2056 3-101-633201 S.A',
#  'VICTORIA SAGOT': 'Casa 2057 Victoria Sagot',
#  'JORGE EDUARDO SOTO SILES': 'Casa 2058  Jorge Eduardo Soto Siles',
#  'JAIME SOLANO': 'Casa 2059 Jaime Solano',
#  'LAGUNA DEL PARAISO': 'Casa 2066 Laguna del Paraiso',
#  'GUEVARA Y LORENZINI S.A.': 'Casa 2067 Guevara y Lorenzini S.A.',
#  'VALVERDE ACOSTA CARMEN MARIA': 'Casa 2068-A Valverde Acosta Carmen Maria',
#  'CARMEN VALVERDE': 'Casa 2068-B Carmen Valverde',
#  'GLADYS CAMPOS VEGA- JIMMY SIBAJA CARVAJAL': 'Casa 2069 Gladys Campos Vega- Jimmy Sibaja Carvajal',
#  'MARIAMALIA JIMENEZ ARRIETA': 'Casa 2070 Mariamalia Jimenez Arrieta',
#  'JORGE ALFARO ULATE': 'Casa 2071 Jorge Alfaro Ulate',
#  'RONALD GONZALEZ': 'Casa 2073 Ronald Gonzalez',
#  'XINIA ALLUIM': 'Casa 2073-A Xinia Alluim',
#  'EDGAR VALVERDE ACOSTA': 'Casa 2073-B Edgar Valverde Acosta',
#  'CORP. BUTMAN': 'Casa 2074 Corp. Butman',
#  'KARLA ARGUELLO': 'Casa 2075 Karla Arguello',
#  'GUIESDANI SOCIEDAD ANONIMA': 'Casa 2076-GUIESDANI SOCIEDAD ANONIMA',
#  'JORGE TORRES': 'Casa 2077 Jorge Torres',
#  'ROSALBA JIMENEZ': 'Casa 2078 Rosalba Jimenez',
#  'GRACE MARTINEZ': 'Casa 2079 Grace Martinez',
#  'ALBERTO CAMPOS': 'Casa 2080 Alberto Campos',
#  'MAURICIO CAMPOS': 'Casa 2081-C Mauricio Campos',
#  'LILLIANA HERNANDEZ MARTINEZ': 'Casa 2082 Lilliana Hernandez Martinez',
#  'DACE S.A.': 'Casa 2083 DACE S.A.',
#  'FERNANDO VARGAS': 'Casa 2084 Fernando Vargas',
#  'ADA TORRES LOBO': 'Casa 2088 Ada Torres Lobo',
#  'INGELECOM S.A': 'Casa 2089 Ingelecom S.A',
#  'FERNANDO NAVARRO CRUZ': 'Casa 2091 Fernando Navarro Cruz',
#  'JUAN FRANCISCO MARTINEZ PEREZ': 'Casa 2092 Juan Francisco Martinez Perez',
#  'RONALD DORMOND': 'Casa 2094  Ronald Dormond',
#  'TOMAS GUEVARA': 'Casa 2095 Tomas Guevara',
#  'GORDON BAIRD': 'Casa 2096 Gordon Baird',
#  'ARTURO PORTELA': 'Casa 2097-2098 Arturo Portela',
#  'ROSA MILA GONZALEZ': 'Casa 2099 Rosa Mila Gonzalez',
#  'NILO A. RAMOS': 'Casa 2100 Nilo A. Ramos',
#  'BERNARDO SOTO': 'Casa 2101 Bernardo Soto',
#  'OFELIA ROJAS': 'Casa 2102 Ofelia Rojas',
#  'SILVIA ROJAS AGUILAR': 'Casa 2103 Silvia Rojas Aguilar',
#  'JORGE EDO. RAMOS ROJAS': 'Casa 2104 Jorge Edo. Ramos Rojas',
#  'MARIA ELENA HERRERA GRANDA': 'Casa 2105 Maria Elena Herrera Granda',
#  'GLADYS CORRALES': 'Casa 2106-A Gladys Corrales',
#  'BEN JEFFERY NIX': 'Casa 2106-B Ben Jeffery Nix',
#  'GLADIS CORRALES CORRALES': 'Casa 2107 Gladis Corrales Corrales',
#  'BIO-EXCEL DE COSTA RICA S.A.': 'Casa 2108 Bio-Excel de Costa Rica S.A.',
#  'ADELIA MONTEALEGRE': 'Casa 2109-A Adelia Montealegre',
#  'CAROLINA RODRIGUEZ': 'Casa 2109-B Carolina Rodriguez',
#  'MARGARITA CAPMANY': 'Casa 2110 Margarita Capmany',
#  'ISABEL MORA CALDERON': 'Casa 2111 Isabel Mora Calderon',
#  'LIGIA RIVERA MORA': 'Casa 2112 Ligia Rivera Mora',
#  'GENARO BLOTTA': 'Casa 2113 Genaro Blotta',
#  'JOSE NEFTALI GONZALEZ': 'Casa 2114 Jose Neftali Gonzalez',
#  'NANCY URENA GUTIERREZ': 'casa 2115 Nancy Urena Gutierrez',
#  'LEONEL CHACON': 'casa 2116 Leonel Chacon',
#  'HABIB PARAJELES LEON': 'Casa 2117 Habib Parajeles Leon',
#  'EDGAR SOTO': 'Casa 2118 Edgar Soto',
#  'CARLOS CARMONA': 'Casa 2119 Carlos Carmona',
#  'GLEN WOODLEY': 'Casa 2120 Glen Woodley',
#  'CAROLINA CORONADO HERNANDEZ': 'Casa 2121 Carolina Coronado Hernandez',
#  'JORGE ROJAS': 'Casa 2122 Jorge Rojas',
#  'VARGAS VIDECHE ROBERTO': 'Casa 2123 Vargas Videche Roberto',
#  'MAURICIO AYALA': 'casa 2124 Mauricio Ayala',
#  'LUIS M. SANCHO CORONADO': 'Casa 2125 Luis M. Sancho Coronado',
#  'EVELYN SOLANO': 'Casa 2126 Evelyn Solano',
#  'RESIDENCIAS DOS MARIAS': 'Casa 2128 Residencias Dos Marias',
#  'ZEIDY ROJAS SOLANO': 'Casa 2129-A Zeidy Rojas Solano',
#  'JAIME FRANCO': 'Casa 2129-B Jaime Franco',
#  'JOSE ALBEIRO GALLEGO V.': 'Casa 2130-A Jose Albeiro Gallego V.',
#  'GERARDO RAMIREZ': 'Casa 2130-B Gerardo Ramirez',
#  'MYRNA REYES': 'Casa 2131 Myrna Reyes',
#  'FELICIA VARGAS': 'Casa 2132 Felicia Vargas',
#  'GLORIA NINO': 'Casa 2134 Gloria Nino',
#  'MABEL VILLALTA': 'Casa 2135 Mabel Villalta',
#  'BANCO COSTA RICA': 'casa 2136 BANCO COSTA RICA',
#  'MARIA EUGENIA CARRERA': 'Casa 2137 Maria Eugenia Carrera',
#  'FREDDY ALVAREZ GUADAMUZ': 'Casa 2138 Freddy Alvarez Guadamuz',
#  'GUILLERMO RAMIREZ SEGNINI': 'Casa 2139 Guillermo Ramirez Segnini',
#  'LUIS FERNANDO ECHEVERRI PALACIO': 'Casa 2140Luis Fernando Echeverri Palacio',
#  'DANIEL CASTILLO': 'Casa 2142 Daniel Castillo',
#  'ELIAS GONZALEZ': 'Casa 2146 Elias Gonzalez',
#  'VIRGINIA GONZALEZ GARCIA': 'Casa 2147-A Virginia Gonzalez Garcia',
#  'VIRGINIA GONZALEZ': 'Casa 2147-B Virginia Gonzalez',
#  'DORA CHINCHILLA': 'Casa 2148 Dora Chinchilla',
#  'CARLOS G. ESCALANTE UGALDE': 'Casa 2149 Carlos G. Escalante Ugalde',
#  'JULIAN IRIO RIVAS': 'Casa 2150 Julian Irio Rivas',
#  'DANNYS CAMPOS CALDERON': 'Casa 2151 Dannys Campos Calderon',
#  'FRANCISCO FERNANDEZ BERMUDEZ': 'Casa 2153 Francisco Fernandez Bermudez',
#  'CIG ALA ROX S.A': 'Casa 2154 Cig Ala Rox S.A',
#  'CONDOMINIO FERNANDEZ Y CASTRO': 'Casa 2155 Condominio Fernandez y Castro',
#  'VERONICA SOLORZANO': 'Casa 2156- Veronica Solorzano',
#  'ZAINDEL GARRETA VEGA': 'Casa 2157 Zaindel Garreta Vega',
#  'VICTOR MAIRENA': 'Casa 2158 Victor Mairena',
#  'WALDA PAZ': 'Casa 2159-A Walda Paz',
#  'JOSE DAVID RODRIGUEZ': 'Casa 2159-B Jose David Rodriguez',
#  'LUIS MAGANA': 'Casa 2160 Luis Magana',
#  'MOLIMOR J.S. S.R.L.': 'Casa 2161 Molimor J.S. S.R.L.',
#  'TAMARA GOMEZ SOLIS': 'Casa 2162 Tamara Gomez Solis',
#  'INV. SELENIA GONZ.': 'Casa 2162-B  Inv. Selenia Gonz.',
#  'EDUARDO MOLINA': 'Casa 2164  Eduardo Molina',
#  'JOSE ANGEL SOLORZANO': 'Casa 2165  Jose Angel Solorzano',
#  'RHODA ALARCON Y MONTES DE OCA': 'Casa 2166-A Rhoda Alarcon y Montes de Oca',
#  'CORPORACION KYRA S.A': 'Casa 2166-B Corporacion Kyra S.A',
#  'JAMES JOSEPH EIDEN-03': 'Casa 2166-C James Joseph Eiden-03',
#  'SOCIEDAD FONDEBADON S.A.': 'Casa 2166-D Sociedad Fondebadon S.A.',
#  'BARRY HIRABAYASHI': 'Casa 2166-E Barry Hirabayashi',
#  'F IRENE SOTO CHAVARRIA': 'Casa 2166-F Irene Soto Chavarria',
#  'G ANTONIO ERANA ROJAS': 'Casa 2166-G Antonio Erana Rojas',
#  'H VANESSA CHACON - 08': 'Casa 2166-H Vanessa Chacon - 08',
#  'I STEVE DAVENBORT': 'Casa 2166-I Steve Davenbort',
#  'J CRISTINA MONGE': 'Casa 2166-J Cristina Monge',
#  'K BERNARDO ALFARO SOTO': 'Casa 2166-K Bernardo Alfaro Soto',
#  'L ANTONIO ERANA ROJAS': 'Casa 2166-L Antonio Erana Rojas',
#  'M ALLAN VARGAS GONZALEZ': 'Casa 2166-M Allan Vargas Gonzalez',
#  'N MARCO VINICIO ELIZONDO VARGAS': 'Casa 2166-N Marco Vinicio Elizondo Vargas',
#  'O FRANCISCO ALVARADO SEGURA': 'Casa 2166-O Francisco Alvarado Segura',
#  'P ANTONIO ERANA ROJAS': 'Casa 2166-P Antonio Erana Rojas',
#  'Q LUIS RODRIGUEZ GUTIERREZ-17': 'Casa 2166-Q Luis Rodriguez Gutierrez-17',
#  'R OLMAN ALONSO ARGUEDAS -18': 'Casa 2166-R Olman Alonso Arguedas -18',
#  'S HUMBERTO LOPEZ -19': 'Casa 2166-S Humberto Lopez -19',
#  'F&S ARAMON ALTERNATIVA SA': 'Casa 3068 F&S Aramon Alternativa SA'}
